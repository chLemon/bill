# %%
import sys

# setting path
sys.path.append('../')

# %%
from import_bill import read_all_bills
from group_and_statistic import group_and_statistic
from domain import Bill, TradeRecord
from pathlib import Path

# %%
all_trade_records = read_all_bills()[0]

# %%
year_to_month_to_sheet_data = group_and_statistic(all_trade_records)

# %%
# output_dir = Path(__file__).resolve().parent.parent.parent / "output"
output_dir = Path().resolve().parent.parent / "output"

# %%
output_dir
# Out:
# WindowsPath('D:/坚果云/bill/output')

# %%
vars(all_trade_records[0]).keys()
# Out:
# dict_keys(['trade_time', 'trade_type', 'trade_target', 'trade_target_account', 'product', 'income_or_expense', 'amount', 'pay_type', 'status', 'trade_no', 'merchant_no', 'remark', 'bill_type'])

# %%
[field.metadata.get('desc', name)
 for name, field in TradeRecord.__dataclass_fields__.items()]

# %%
[TradeRecord.__dataclass_fields__[k].metadata['desc'] for k in vars(all_trade_records[0]).keys()]
# Out:
# ['交易时间',
#  '交易类型',
#  '交易对方',
#  '交易对方账号',
#  '商品',
#  '收/支',
#  '金额(元)',
#  '支付方式',
#  '当前状态',
#  '交易单号',
#  '商户单号',
#  '备注',
#  '订单类型']

# %%
import csv

# %%
with open('output.csv', 'w', newline='', encoding='utf-8-sig') as f:
    writer = csv.DictWriter(f, fieldnames=vars(obj_list[0]).keys())
    writer.writeheader()
    for obj in obj_list:
        writer.writerow(vars(obj))

# %%
with open('output.csv', 'w', newline='', encoding='utf-8-sig') as f:
    writer = csv.writer(f)
    writer.writerow(["name", "age"])
    writer.writerow(["Alice", 25])
    writer.writerow(["Bob"])

# %%
import csv

rows = [
    ["name", "age"],
    ["Alice", 25],
    ["Bob"]
]

with open('output.csv', 'w', newline='', encoding='utf-8-sig') as f:
    writer = csv.writer(f)
    writer.writerows(rows)

# %%
import csv

# 假设 data 是一个字典列表
data = [
    {"name": "Alice", "age": 25},
    {"name": "Bob", "age": 30}
]

with open('output.csv', 'w', newline='', encoding='utf-8-sig') as f:
    writer = csv.DictWriter(f, fieldnames=data[0].keys())
    # writer.writeheader()
    writer.writerows(data)

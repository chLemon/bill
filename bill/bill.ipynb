# %% [markdown]
# 1. 读取账单数据
#    1. 给出开始时间和结束时间
#    2. 给出不同账单时间的diff
#    3. 数据经过去重、排序
# 2. 数据合并
#    1. 退款和支出
#    2. 不同银行卡
# 3. 按时间分组、做统计分析
# 4. 输出到Excel

# %%
from import_bill import read_all_bills
from domain import Bill, TradeRecord
from pathlib import Path

# %%
all_trade_records,bill_time_range = read_all_bills()

# %%
len(all_trade_records)
# Out:
# 153

# %%
bill_time_range
# Out:
# {'微信': [(datetime.datetime(2025, 3, 7, 0, 0),
#    datetime.datetime(2025, 5, 7, 21, 52, 3))],
#  '支付宝': [(datetime.datetime(2025, 4, 7, 0, 0),
#    datetime.datetime(2025, 5, 7, 23, 59, 59))]}

# %%
from group_and_statistic import group_and_statistic

# %%
year_to_month_to_group_data = group_and_statistic(all_trade_records=all_trade_records)
year_to_month_to_group_data
# Out:
# {2025: {3: <domain.SheetData.SheetData at 0x1fcca19bf70>,
#   4: <domain.SheetData.SheetData at 0x1fcca19bf10>,
#   5: <domain.SheetData.SheetData at 0x1fcca19b880>}}

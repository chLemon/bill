# %% [markdown]
# csv, utf-8

# %%
import os

folder_path = '../../data/微信'  # 替换为你的文件夹路径
files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
print(files)
# Out:
# ['微信支付账单(20250407-20250507)——【解压密码可在微信支付公众号查看】.csv']
